# %%
import sys
import os
import zipfile
from scipy import stats

## import function from python_scripts
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
if parent_dir not in sys.path:
    sys.path.append(parent_dir)
    
from python_scripts.gene_level_MoM import * 
from python_scripts.pairwise_product_var_calculation import * 
from python_scripts.visualization import * 
from python_scripts.weight_function import *

# %%
### Read all data
individual_sizes = [1000,2000,4000,8000]

Random_STD = read_MoM_results(individual_sizes,"../test_data/result_328/","Random_STD",1000)
Contiguous_STD = read_MoM_results(individual_sizes,"../test_data/result_328/","Contiguous_STD",1000)

# %%
print("Contiguous_STD")
individual_sizes = [1000, 2000, 4000,8000]
x_labels1 = ["m = 1000"]

plot_relative_error_across_groups_combined(
    Contiguous_STD,     
    x_labels=x_labels1,
    individual_sizes=individual_sizes,
    col_num=0,
    real_value=0.9,
    ymin=-1,
    ymax=1,
    x_axis_name="Number of SNP",
    title = "sds"
)
# Out:
# Contiguous_STD
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       2 individual_sizes = [1000, 2000, 4000,8000]
#       3 x_labels1 = ["m = 1000"]
# ----> 5 plot_relative_error_across_groups_combined(
#       6     Contiguous_STD,
#       7     x_labels=x_labels1,
#       8     individual_sizes=individual_sizes,
#       9     col_num=0,
#      10     real_value=0.9,
#      11     ymin=-1,
#      12     ymax=1,
#      13     x_axis_name="Number of SNP",
#      14     title = "sds"
#      15 )
#
# TypeError: plot_relative_error_across_groups_combined() got an unexpected keyword argument 'title'
